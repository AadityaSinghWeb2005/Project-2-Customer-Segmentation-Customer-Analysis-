# %%
#==============================
#PHASE-1 Data Loading & Data understanding
#==============================

import pandas as pd
import numpy as np 

df = pd.read_csv('Data.csv')
#--Top 5 and bottom 5 columns --#
df.head(5)
df.tail(5)

#--No. of Rows and Column--#
print(f'Rows in this data set are : {df.shape[0]} and No. of columns in this data set are : {df.shape[1]}')

#--Column Names--#
Columns = list(df.columns)
print(Columns)

#--Data Type of every Column---#
df.info()


#========================
#PHASE-2 Data Cleaning and Type conversion
#========================


df['Subscription Date'] = pd.to_datetime('Subscription Date')
df['Subscription Year'] = df['Subscription Date'].dt.year

df
# Out:
# Rows in this data set are : 100000 and No. of columns in this data set are : 12
# ['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City', 'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date', 'Website']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Index              100000 non-null  int64
#  1   Customer Id        100000 non-null  object
#  2   First Name         100000 non-null  object
#  3   Last Name          100000 non-null  object
#  4   Company            100000 non-null  object
#  5   City               100000 non-null  object
#  6   Country            100000 non-null  object
#  7   Phone 1            100000 non-null  object
#  8   Phone 2            100000 non-null  object
#  9   Email              100000 non-null  object
#  10  Subscription Date  100000 non-null  object
# ...
